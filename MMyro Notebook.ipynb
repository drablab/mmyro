# %%
from myro import *
# Out:
# (c) 2006-2007 Institute for Personal Robots in Education
# [See http://www.roboteducation.org/ for more information]
# Myro version 5.0.1 is ready!

# %%
init('/dev/rfcomm0')
# Out:
# You are using fluke firmware 3.0.9
# You are using scribbler firmware 1.1.6
# Hello, I'm Scribby!

# %%
getBattery()
# Out:
# 5.862363151949593

# %%
p = takePicture()

# %%
p
# Out:
# <PIL.Image.Image image mode=RGBA size=1280x800 at 0x7F16C6439890>

# %%
p.image
# Out:
# <PIL.Image.Image image mode=RGBA size=1280x800 at 0x7F16C6439890>

# %%
show(p)
# Out:
# <PIL.Image.Image image mode=RGBA size=1280x800 at 0x7F16C6439890>

# %%
for i in range(10):
    p = takePicture()
    show(p)

# %%
show(p)
# Out:
# <PIL.Image.Image image mode=RGBA size=1280x800 at 0x7F16C63CDFD0>

# %%
from IPython.display import display
display(p)
# Out:
# <PIL.Image.Image image mode=RGBA size=1280x800 at 0x7F16C63CDFD0>
